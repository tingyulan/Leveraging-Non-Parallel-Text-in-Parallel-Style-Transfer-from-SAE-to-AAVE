# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Colab\ Notebooks/4650Project/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/4650Project

# %%
# %pwd
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/4650Project'

# %% [markdown]
# Loading Data

# %%
import pandas as pd
from pprint import pprint

# %%
#Load SAE for training
f = open("data_new/sae/train.paraphrased.txt", "r")
sae_paraphrase_train = f.read().split('\n')
print(len(sae_paraphrase_train))
pprint(sae_paraphrase_train[0:10])
# Out:
# 1616
# ["a man pretending to be a woman had a relationship with Manti Te'o via the "
#  'phone.',
#  "the little girl won't win because I'm the king, so she's got to stop what "
#  "she's doing.",
#  "now I'm upstairs and I'm downstairs.",
#  "I'm sorry, but I'm doing it for Shaq and my kids this year.",
#  "I don't plan on losing it, no matter the cost, but I'm not planning on "
#  'losing it.',
#  "when he's good at rap, he'll shout out to Nestboy Vick.",
#  "and the Miami Heat's Lebron James had 34 points, 16 rebounds, 7 assists, 3 "
#  'steals, and 1 block.',
#  "you can say anything you want, I'm not interested.",
#  "I'll be home by 3: 45, and I'll be leaving the PSM.",
#  "if they don't answer the phone, they don't care about it."]

# %%
#Load AAE for training
f = open("data_new/aae/train.paraphrased.txt", "r")
aae_paraphrase_train = f.read().split('\n')
print(len(aae_paraphrase_train))
pprint(aae_paraphrase_train[0:10])
# Out:
# 1616
# ['a guy pretending to be a woman - - - was having a relationship with Manti '
#  "Te'o.",
#  'the little girl is not going to win...... so I better go.',
#  "now I'm going to go down the stairs and I'm ready to go.",
#  "I'm the one who's gonna do it this year, or I'm gonna fuck up my kids.",
#  "I don't plan on losing it, but it's very rare that I'm going to get what I "
#  'want.',
#  "shout to the boy vick, he's cold, he's gonna drop the rap.",
#  'Miami Boston James Points: 34 Reb: 16 Ast: 7 Stl: 3 Blk: 1 Garnett Points: '
#  '24 Reb: 11 Ast: 4 Stl: 2',
#  'you can tell me anything you want, no one else can have you.',
#  "I should be at home by 3: 45 when the bell rings and I'm supposed to go to "
#  'the house!',
#  "if he doesn't answer, he doesn't mean he didn't give a shit."]

# %%
#Load SAE for dev
f = open("data_new/sae/dev.paraphrased.txt", "r")
sae_paraphrase_dev = f.read().split('\n')
print(len(sae_paraphrase_dev))
pprint(sae_paraphrase_dev[0:10])
# Out:
# 203
# ["I'm tired, and I'm glad I'm not working for a couple of weeks.",
#  "I'm tired and I can't go today, so I'm going to work.",
#  "it's crazy because black men lie to their hoes, saying they don't have a "
#  'girlfriend, but they have a whole one.',
#  "the louder you are, the less noise you'll hear (the less people you'll be).",
#  "I'm not promising much, but I promise to give you my best shot!",
#  "I'm not gonna believe shit he's saying.",
#  'we went shopping, then we went to the salon, then we went to the ball.',
#  "it's funny, I sent Quinton a joke emoji.",
#  "you're just a conversation piece, you're just a piece of shit.",
#  'they chased the car to EC last year.']

# %%
#Load AAE for dev
f = open("data_new/aae/dev.paraphrased.txt", "r")
aae_paraphrase_dev = f.read().split('\n')
print(len(aae_paraphrase_dev))
pprint(aae_paraphrase_dev[0:10])
# Out:
# 203
# ["hell, I'm tired of being shut down for a couple of weeks in Miami.",
#  "I'm working on my day, I'm used to work tires, so I'm happy to work.",
#  "he's crazy about the fact that he says he doesn't have a girlfriend, but "
#  "he's got a whole one.",
#  "the louder you go, the less noise you'll hear (less people at the top).",
#  "I'm thinking of the day: I'm not promising much, but I promise you, dear "
#  "life, I'll try to do my best.",
#  "I'm not gonna be a clown ass nigga.",
#  'we went shopping, then we went to dinner, then we went to the dance.',
#  "Ik, we're thinking the same thing, so Quinton, he's gonna be Quinton.",
#  "you're just a piece of shit, Luv.",
#  'they chased the car to EC last year.']

# %%
#Load SAE for test
f = open("data_new/sae/test.paraphrased.txt", "r")
sae_paraphrase_test = f.read().split('\n')
print(len(sae_paraphrase_test))
pprint(sae_paraphrase_test[0:10])
# Out:
# 203
# ['"the silver lining"? Really, you\'re worried about the Heat winning?',
#  "I'm going to play you in Chicago, but I'll still have a game.",
#  'on September 4, 2013, I will play the old-school and house music again...',
#  'I jumped out of the plane, but I drank too much.',
#  "you're not right to keep a tweet.",
#  "you have a baby, and it's too young for a baby.",
#  "it's time to recognize obesity as a disease.",
#  "I missed the first few and I'd like to go.",
#  'she wanted to recreate the Plantation Wedding, which she liked the nostalgia '
#  'of the time?',
#  'the taste of the nation was a silent auction item.']

# %%
#Load AAE for test
f = open("data_new/aae/test.paraphrased.txt", "r")
aae_paraphrase_test = f.read().split('\n')
print(len(aae_paraphrase_test))
pprint(aae_paraphrase_test[0:10])
# Out:
# 203
# ['"the Silver Lining" is a real jerk?',
#  "I'm gonna play you in Chi city... if you're in Chi... Lol.",
#  'on September 4, 2013, due to the annual jazz festival...',
#  "I jumped out of the plane, but I'm not sure if I'd jump out of the plane.",
#  "you're crazy if you're late for work.",
#  "if you don't have a baby, you have to have a baby.",
#  'people have 2 meals, no 1 is 2, both have drugs and drinks.',
#  "missed the first few, but I'd like to stop by.",
#  'she wanted to recreate the Plantation wedding, which she liked the nostalgia '
#  'of the period?',
#  "the taste of the nation's silent auction was cheese."]

# %%
# data_train = []
# data_eval = []
# for i in range(len(aae_paraphrase_train)):
#   pair = [sae_paraphrase_train[i], aae_paraphrase_train[i]]
#   data_train.append(pair)
# for i in range(len(aae_paraphrase_dev)):
#   pair = [sae_paraphrase_dev[i], aae_paraphrase_dev[i]]
#   data_eval.append(pair)
# print(len(data_train))
# print(len(data_eval))

# %%
data_train = {}
data_train['sae'] = sae_paraphrase_train
data_train['aave'] = aae_paraphrase_train
data_val = {}
data_val['sae'] = sae_paraphrase_dev
data_val['aave'] = aae_paraphrase_dev
data_test = {}
data_test['sae'] = sae_paraphrase_test
data_test['aave'] = aae_paraphrase_test

# %%
import pandas as pd

# %%
data_train = pd.DataFrame(data_train)
data_train
# Out:
#                                                     sae                                               aave
# 0     a man pretending to be a woman had a relations...  a guy pretending to be a woman - - - was havin...
# 1     the little girl won't win because I'm the king...  the little girl is not going to win...... so I...
# 2                  now I'm upstairs and I'm downstairs.  now I'm going to go down the stairs and I'm re...
# 3     I'm sorry, but I'm doing it for Shaq and my ki...  I'm the one who's gonna do it this year, or I'...
# 4     I don't plan on losing it, no matter the cost,...  I don't plan on losing it, but it's very rare ...
# ...                                                 ...                                                ...
# 1611  we were behind him because he wanted the shoes...                         get off my Jordan's hands!
# 1612  if they win, it's the easiest night for findin...  if they win, it's the easiest night for ass in...
# 1613  I want to come back when your ex likes the pic...  when your ex likes your pictures on Instagram,...
# 1614  I'm not saying it, but a lot of these guys on ...  I'm not saying it, but a lot of these niggas o...
# 1615
#
# [1616 rows x 2 columns]

# %%
data_val = pd.DataFrame(data_val)
data_val
# Out:
#                                                    sae                                               aave
# 0    I'm tired, and I'm glad I'm not working for a ...  hell, I'm tired of being shut down for a coupl...
# 1    I'm tired and I can't go today, so I'm going t...  I'm working on my day, I'm used to work tires,...
# 2    it's crazy because black men lie to their hoes...  he's crazy about the fact that he says he does...
# 3    the louder you are, the less noise you'll hear...  the louder you go, the less noise you'll hear ...
# 4    I'm not promising much, but I promise to give ...  I'm thinking of the day: I'm not promising muc...
# ..                                                 ...                                                ...
# 198  I've never talked to anyone in high school and...  ... I've been fucked up by Mfers in my grammar...
# 199  no, she didn't hold her hands, bow, and pray t...  no one held hands, bowed to the ground, and pr...
# 200           I'm not hungry yesterday, but I'm tired.  I guess yesterday was a little weird because I...
# 201  a cross-dresser who has a great job or a good ...  a cross-dresser who has a great job or a good ...
# 202
#
# [203 rows x 2 columns]

# %%
data_test = pd.DataFrame(data_test)
data_test
# Out:
#                                                    sae                                               aave
# 0    "the silver lining"? Really, you're worried ab...                "the Silver Lining" is a real jerk?
# 1    I'm going to play you in Chicago, but I'll sti...  I'm gonna play you in Chi city... if you're in...
# 2    on September 4, 2013, I will play the old-scho...  on September 4, 2013, due to the annual jazz f...
# 3     I jumped out of the plane, but I drank too much.  I jumped out of the plane, but I'm not sure if...
# 4                    you're not right to keep a tweet.              you're crazy if you're late for work.
# ..                                                 ...                                                ...
# 198  if you call it, it's just ad-libbing, but it's...              if you call it, it's a singing group.
# 199                   contact Reggie Kelly 410-645-049  ISO is a great place to sing or dance to a cli...
# 200  I'm looking for a "mature" establishment, 45-5...  a "Grown Folks" clientele; 45-50 and older. R ...
# 201  when I was in the store, I thought I'd put the...  I went to the store to get something to eat, s...
# 202
#
# [203 rows x 2 columns]

# %% [markdown]
# #Training start here:

# %%
# !pip install sentencepiece==0.1.91
# Out:
# Collecting sentencepiece==0.1.91
#   Downloading sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 15.4 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.91

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 14.5 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 85.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 71.4 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 500 kB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 73.6 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5

# %%
import torch
import transformers
import pandas as pd
from pprint import pprint
from tqdm.notebook import tqdm

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels, length):
        self.encodings = encodings
        self.labels = labels
        self.length = length

    def __getitem__(self, idx):
        encoding_item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        label_item = {key: torch.tensor(val[idx]) for key, val in self.labels.items()}
        return encoding_item, label_item

    def __len__(self):
        return self.length

def get_dataset(train, val):
    '''
    train: list of [sae, aave] for training 
    val: list of [sae, aave] for validation
    '''
    #from transformers import BartTokenizerFast
    from transformers import T5Tokenizer

    #tokenizer = BartTokenizerFast.from_pretrained('facebook/bart-base')
    tokenizer = T5Tokenizer.from_pretrained('t5-base')

    train_sae = tokenizer(list(train['sae']), padding=True)
    train_aave = tokenizer(list(train['aave']), padding=True)
    val_sae = tokenizer(list(val['sae']), padding=True)
    val_aave = tokenizer(list(val['aave']), padding=True)

    train_dataset = Dataset(train_sae, train_aave, length = len(list(train['sae'])))
    val_dataset = Dataset(val_sae, val_aave, length=len(list(val['sae'])))

    return train_dataset, val_dataset

# %%
from transformers import T5Tokenizer
tokenizer = T5Tokenizer.from_pretrained('t5-base')
print(tokenizer)
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# PreTrainedTokenizer(name_or_path='t5-base', vocab_size=32100, model_max_len=512, is_fast=False, padding_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'additional_special_tokens': ['<extra_id_0>', '<extra_id_1>', '<extra_id_2>', '<extra_id_3>', '<extra_id_4>', '<extra_id_5>', '<extra_id_6>', '<extra_id_7>', '<extra_id_8>', '<extra_id_9>', '<extra_id_10>', '<extra_id_11>', '<extra_id_12>', '<extra_id_13>', '<extra_id_14>', '<extra_id_15>', '<extra_id_16>', '<extra_id_17>', '<extra_id_18>', '<extra_id_19>', '<extra_id_20>', '<extra_id_21>', '<extra_id_22>', '<extra_id_23>', '<extra_id_24>', '<extra_id_25>', '<extra_id_26>', '<extra_id_27>', '<extra_id_28>', '<extra_id_29>', '<extra_id_30>', '<extra_id_31>', '<extra_id_32>', '<extra_id_33>', '<extra_id_34>', '<extra_id_35>', '<extra_id_36>', '<extra_id_37>', '<extra_id_38>', '<extra_id_39>', '<extra_id_40>', '<extra_id_41>', '<extra_id_42>', '<extra_id_43>', '<extra_id_44>', '<extra_id_45>', '<extra_id_46>', '<extra_id_47>', '<extra_id_48>', '<extra_id_49>', '<extra_id_50>', '<extra_id_51>', '<extra_id_52>', '<extra_id_53>', '<extra_id_54>', '<extra_id_55>', '<extra_id_56>', '<extra_id_57>', '<extra_id_58>', '<extra_id_59>', '<extra_id_60>', '<extra_id_61>', '<extra_id_62>', '<extra_id_63>', '<extra_id_64>', '<extra_id_65>', '<extra_id_66>', '<extra_id_67>', '<extra_id_68>', '<extra_id_69>', '<extra_id_70>', '<extra_id_71>', '<extra_id_72>', '<extra_id_73>', '<extra_id_74>', '<extra_id_75>', '<extra_id_76>', '<extra_id_77>', '<extra_id_78>', '<extra_id_79>', '<extra_id_80>', '<extra_id_81>', '<extra_id_82>', '<extra_id_83>', '<extra_id_84>', '<extra_id_85>', '<extra_id_86>', '<extra_id_87>', '<extra_id_88>', '<extra_id_89>', '<extra_id_90>', '<extra_id_91>', '<extra_id_92>', '<extra_id_93>', '<extra_id_94>', '<extra_id_95>', '<extra_id_96>', '<extra_id_97>', '<extra_id_98>', '<extra_id_99>']})

# %%
train_dataset, val_dataset = get_dataset(data_train, data_val)

# %%
print(len(train_dataset))
print(type(train_dataset))
# Out:
# 1616
# <class '__main__.Dataset'>

# %%
import torch
from torch.nn import BCEWithLogitsLoss, BCELoss

from torch.utils.data import DataLoader

#from transformers import BartForConditionalGeneration, AdamW
from transformers import T5Tokenizer, T5ForConditionalGeneration, AdamW

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())
print(device)

#model =  BartForConditionalGeneration.from_pretrained('facebook/bart-base')
model = T5ForConditionalGeneration.from_pretrained('t5-base')

model.to(device)
model.train()

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=False)

optim = AdamW(model.parameters(), lr=5e-5)
# Out:
# True
# cuda
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
WEIGHT_PATH = 'weights/T5_new'

# %%
def train(epochs=10):
    train_loss_set = list()
    for epoch in tqdm(range(epochs)):
        for batch in train_loader:
            input, label = batch
            #print(input)

            optim.zero_grad()

            input_ids = input['input_ids'].to(device)
            attention_mask = input['attention_mask'].to(device)

            labels = label['input_ids'].to(device)
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs[0]
            train_loss_set.append(loss.item())

            # Backward pass
            loss.backward()

            optim.step()

        print("Finished epoch {}".format(epoch))

    model.save_pretrained(WEIGHT_PATH)
    return train_loss_set

# %%
loss_values = train(10)

import matplotlib.pyplot as plt

plt.plot(loss_values)
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Finished epoch 0
# Finished epoch 1
# Finished epoch 2
# Finished epoch 3
# Finished epoch 4
# Finished epoch 5
# Finished epoch 6
# Finished epoch 7
# Finished epoch 8
# Finished epoch 9

# %%
WEIGHT_PATH = 'weights/T5_new'

# %%
#DATAPATH = 'data/training/test.csv'
import torch

# from transformers import BartTokenizerFast
# tokenizer = BartTokenizerFast.from_pretrained('facebook/bart-base')

from transformers import T5Tokenizer
tokenizer = T5Tokenizer.from_pretrained('t5-base')

def get_data(data):

  sae_list = list(data['sae'])
  aave_list = list(data['aave'])
  return sae_list, aave_list

class TestDataset(torch.utils.data.Dataset):
  def __init__(self, encodings, inputs, labels, length):
      self.encodings = encodings
      self.inputs = inputs
      self.labels = labels
      self.length = length

  def __getitem__(self, idx):
      encoding_item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
      return (encoding_item, self.inputs[idx], self.labels[idx])

  def __len__(self):
      return self.length

def get_dataset(sae_list, aave_list):

  sae_encodings = tokenizer(sae_list, padding=True)

  test_dataset = TestDataset(encodings = sae_encodings, inputs = sae_list, labels = aave_list, length = len(aave_list))

  return test_dataset

# %%
sae_list, aave_list = get_data(data_test)
test_dataset = get_dataset(sae_list, aave_list)
# print(test_dataset.inputs)
# print(test_dataset.labels)

# %%
from transformers import T5ForConditionalGeneration
#from transformers import BartForConditionalGeneration

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm

def validate(val_dataset):
    model =  T5ForConditionalGeneration.from_pretrained(WEIGHT_PATH)
    #model =  BartForConditionalGeneration.from_pretrained(WEIGHT_PATH)
    model.to(device)
    model.eval()

    val_loader = DataLoader(val_dataset, batch_size=5, shuffle=False)

    print("Evaluating on {} questions".format(len(val_dataset)))
    
    org_inputs = []
    generated_texts = []
    references = []
    for batch in val_loader:
            input, org_input, reference = batch
            for o in org_input:
              org_inputs.append(o)
            for r in reference:
              references.append(r)

            input_ids = input['input_ids'].to(device)
            attention_mask = input['attention_mask'].to(device)

            with torch.no_grad():
                generated_sequences = model.generate(
                    input_ids=input_ids,
                    attention_mask = attention_mask,
                    max_length=600,
                    temperature=0.8,
                    top_k=5,
                    top_p=0.9,
                    repetition_penalty=0.8
                    )
                #print(generated_sequences)
                for sequence in generated_sequences:
                    hypothesis = tokenizer.decode(sequence, clean_up_tokenization_spaces=True)
                    print(hypothesis)
                    hypothesis = hypothesis[5:]
                    #print(hypothesis)
                    if '</s>' in hypothesis:
                        end = hypothesis.index('</s>')
                    else:
                        end = 0
                    hypothesis = hypothesis[0:end]
                    generated_texts.append(hypothesis)
    return org_inputs, generated_texts, references

# %%
org_inputs, generated_texts, references = validate(test_dataset)
# Out:
# Evaluating on 203 questions

# %%
print(len(org_inputs))
print(len(generated_texts))
print(len(references))
# Out:
# 203
# 203
# 203

# %%
for i in range(0,10):
  print(org_inputs[i])
  print(references[i])
  print(generated_texts[i])
  print('==========================================================================')
# Out:
# "the silver lining"? Really, you're worried about the Heat winning?
# "the Silver Lining" is a real jerk?
#  I'm sure the Heat will win the game, but they'll be the last ones to win the game.
# ==========================================================================
# I'm going to play you in Chicago, but I'll still have a game.
# I'm gonna play you in Chi city... if you're in Chi... Lol.
#  I'm going to play you in Chicago, but I'm going to play you in Chicago.
# ==========================================================================
# on September 4, 2013, I will play the old-school and house music again...
# on September 4, 2013, due to the annual jazz festival...
#  on September 4, 2013, I'll play the old-school and house music again...
# ==========================================================================
# I jumped out of the plane, but I drank too much.
# I jumped out of the plane, but I'm not sure if I'd jump out of the plane.
#  I jumped out of the plane, but I drank too much.
# ==========================================================================
# you're not right to keep a tweet.
# you're crazy if you're late for work.
#  you're not gonna keep a tweeting nigger you're gonna keep a tweeting nigger you're gonna keep a tweeting nigger you're gonna keep a tweeting nigger you're gonna
# ==========================================================================
# you have a baby, and it's too young for a baby.
# if you don't have a baby, you have to have a baby.
#  you have a baby, and it's too young for a baby.
# ==========================================================================
# it's time to recognize obesity as a disease.
# people have 2 meals, no 1 is 2, both have drugs and drinks.
#  it's time to recognize obesity as a disease, not a disease.
# ==========================================================================
# I missed the first few and I'd like to go.
# missed the first few, but I'd like to stop by.
#  I missed the first few and I'd like to go.
# ==========================================================================
# she wanted to recreate the Plantation Wedding, which she liked the nostalgia of the time?
# she wanted to recreate the Plantation wedding, which she liked the nostalgia of the period?
#  she wanted to recreate the Plantation Wedding, which she liked the nostalgia of the time?
# ==========================================================================
# the taste of the nation was a silent auction item.
# the taste of the nation's silent auction was cheese.
#  the taste of the nation was a silent auction item.
# ==========================================================================

# %%
output = {}
output['org_inputs'] = org_inputs
output['references'] = references
output['generated_texts'] = generated_texts
output = pd.DataFrame(output)
output.to_csv("data/T5_new_output.csv", index=False)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 16.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 76.7 MB/s
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.2.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.8.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 82.6 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 68.8 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 73.7 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 83.4 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 86.2 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, datasets
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 datasets-1.16.1 frozenlist-1.2.0 fsspec-2021.11.1 multidict-5.2.0 xxhash-2.0.2 yarl-1.7.2

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.19.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (0.12.0)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4

# %%
import torch
import nltk
import numpy as np
import datasets
from datasets import load_metric
from datetime import datetime

def compute_metrics(predictions, labels):

    # if type(labels) == list:
    #     labels = torch.tensor(labels)

    # # Replace -100 in the labels as we can't decode them.
    # labels = torch.where(labels != -100, labels, tokenizer.eos_token_id)

    # predictions = predictions.cpu()
    # labels = labels.cpu()

    # decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # joined_preds = list(map(lambda x: ''.join(x).replace('\n', ''), decoded_preds))
    # joined_labels = list(map(lambda x: ''.join(x).replace('\n', ''), decoded_labels))

    # Rouge expects a newline after each sentence
    nled_preds = list(map(lambda x: "\n".join(nltk.sent_tokenize(x)), predictions))
    nled_labels = list(map(lambda x: "\n".join(nltk.sent_tokenize(x)), labels))
    print(nled_preds)
    print()

    rouge = load_metric("rouge")
    result = rouge.compute(predictions=nled_preds, references=nled_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}

    # Add mean generated length
    prediction_lens = [torch.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)

    # BERTScore # roberta-large => cuda out of memory
    bertscore = load_metric("bertscore")
    bs_result = bertscore.compute(predictions=joined_preds, references=joined_labels, lang='en')
    result = dict(result, **{'BS ' + k: np.mean(v) for k, v in bs_result.items() if k != 'hashcode'})

    # BLEU
    bleu = load_metric("bleu")
    preds = list(map(lambda x: list(map(lambda y: str(y), x)), joined_preds))
    refs = list(map(lambda x: [list(map(lambda y: str(y), x)),], joined_labels))
    result['bleu'] = bleu.compute(predictions=preds, references=refs)['bleu']

    return {k: v for k, v in result.items()}, joined_preds, joined_labels

# %%
compute_metrics(output['generated_texts'][0], output['references'][0])
# Out:
# ['', 'I', "'", 'm', '', 's', 'u', 'r', 'e', '', 't', 'h', 'e', '', 'H', 'e', 'a', 't', '', 'w', 'i', 'l', 'l', '', 'w', 'i', 'n', '', 't', 'h', 'e', '', 'g', 'a', 'm', 'e', ',', '', 'b', 'u', 't', '', 't', 'h', 'e', 'y', "'", 'l', 'l', '', 'b', 'e', '', 't', 'h', 'e', '', 'l', 'a', 's', 't', '', 'o', 'n', 'e', 's', '', 't', 'o', '', 'w', 'i', 'n', '', 't', 'h', 'e', '', 'g', 'a', 'm', 'e', '.']
# ['"', 't', 'h', 'e', '', 'S', 'i', 'l', 'v', 'e', 'r', '', 'L', 'i', 'n', 'i', 'n', 'g', '"', '', 'i', 's', '', 'a', '', 'r', 'e', 'a', 'l', '', 'j', 'e', 'r', 'k', '?']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-071c3e11a89a> in <module>()
# ----> 1 compute_metrics(output['generated_texts'][0], output['references'][0])
#
# <ipython-input-77-440701bfe595> in compute_metrics(predictions, labels)
#      29
#      30     rouge = load_metric("rouge")
# ---> 31     result = rouge.compute(predictions=nled_preds, references=nled_labels, use_stemmer=True)
#      32     # Extract a few results
#      33     result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
#
# /usr/local/lib/python3.7/dist-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     391
#     392         if predictions is not None:
# --> 393             self.add_batch(predictions=predictions, references=references)
#     394         self._finalize()
#     395
#
# /usr/local/lib/python3.7/dist-packages/datasets/metric.py in add_batch(self, predictions, references)
#     461                     f"Input references: {summarize_if_long_list(references)}"
#     462                 )
# --> 463             raise ValueError(error_msg) from None
#     464
#     465     def add(self, *, prediction=None, reference=None):
#
# ValueError: Mismatch in the number of predictions (83) and references (35)
